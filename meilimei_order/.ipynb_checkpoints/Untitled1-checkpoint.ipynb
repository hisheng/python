# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
orderpath = 'order.csv'
daypath = 'day.csv'

# %%
print(orderpath)
print(daypath)
# Out:
# order.csv
# day.csv

# %%
daydata = pd.read_csv(daypath)
orderdata = pd.read_csv(orderpath)

# %%
daydata
# Out:
#          day        uid dstatus
# 0   20171013      10000     all
# 1   20171013     100200   login
# 2   20171013     104000   order
# 3   20171013     100500     sku
# 4   20171013    1020200     pay
# 5   20171013     100001     all
# 6   20171013    1010200   login
# 7   20171013    1024000   order
# 8   20171013    1030500     sku
# 9   20171013   10420200     pay
# 10  20171013   10240004   order
# 11  20171013   10305030     sku
# 12  20171013  104202040     pay
# 13  20171012     100500     sku
# 14  20171012    1020200     pay
# 15  20171012      10000     all
# 16  20171012    1010200   login
# 17  20171012    1024000   order
# 18  20171012    1030500     sku
# 19  20171012   10420200     pay
# 20  20171011    1010200   login
# 21  20171011    1024000   order
# 22  20171011    1030500     sku
# 23  20171011   10420200     pay
# 24  20171010    1010200   login
# 25  20171010    1024000   order
# 26  20171010    1030500     sku
# 27  20171010   10420200     pay
# ...

# %%
orderdata
# Out:
#         day   num dstatus
# 0  20171013  1000     all
# 1  20171013   100   login
# 2  20171013    30     sku
# 3  20171013     3   order
# 4  20171013     1     pay
# 5  20171012  2000     all
# 6  20171012   150   login
# 7  20171012    60     sku
# 8  20171012     4   order
# 9  20171012     2     pay

# %%
# user 从 全部的 到 login 到 sku 到 order 到 pay 的 转化情况
sns.factorplot(x='dstatus',y='num',data=orderdata,hue='day')
plt.show()

# %%
#日活
sns.countplot(x='day',data=orderdata)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3eda938809fc> in <module>()
#       1 #日活
# ----> 2 sns.countplot(x='day',data=orderdata)
#       3 plt.show()
#
# NameError: name 'sns' is not defined
