# %% [markdown]
# cat_dog_classification_CNN_Flask_App
# https://www.kaggle.com/sidharth178/cat-dog-classification-cnn-flask-app

# %%
import os
catDogDir = '/Users/zhanghaisheng/study/imgs/cat_dog/'
filenames = os.listdir(catDogDir + "training_set/training_set/dogs")
print(filenames[0:20])
# Out:
# ['dog.1753.jpg', 'dog.3144.jpg', 'dog.775.jpg', 'dog.3622.jpg', 'dog.1035.jpg', 'dog.1021.jpg', 'dog.3636.jpg', 'dog.2528.jpg', 'dog.761.jpg', 'dog.3150.jpg', 'dog.1747.jpg', 'dog.991.jpg', 'dog.2266.jpg', 'dog.3178.jpg', 'dog.749.jpg', 'dog.1009.jpg', 'dog.2500.jpg', 'dog.2514.jpg', 'dog.985.jpg', 'dog.2272.jpg']

# %%
import random
import tensorflow as tf 
import matplotlib.pyplot as plt
sample = random.choice(filenames)
print(sample)
img = tf.keras.preprocessing.image.load_img(catDogDir + "training_set/training_set/dogs/"+sample)
plt.imshow(img)
# Out:
# dog.995.jpg
