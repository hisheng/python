# %% [markdown]
# 下载数据库， https://www.kaggle.com/tongpython/cat-and-dog 的cat和dog数据

# %%
import tensorflow as tf
import numpy as np
training_set = tf.keras.preprocessing.image_dataset_from_directory("/Users/zhanghaisheng/study/imgs/cat_dog/training_set/training_set")
test_set = tf.keras.preprocessing.image_dataset_from_directory("/Users/zhanghaisheng/study/imgs/cat_dog/test_set/test_set")
# Out:
# Found 8005 files belonging to 2 classes.
# Found 2023 files belonging to 2 classes.

# %%
test_set
# Out:
# <BatchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int32)>

# %% [markdown]
# Part 2 - Building the CNN
#
# It is done in 5 steps:
#
# 1.Convolution
# 2.Polling
# 3.Flattening
# 4.Full Connection
# 5.Output Layer
# ![image.png](attachment:d30a3969-e3a9-40ea-90ec-e473ee90aab5.png)

# %%
cnn = tf.keras.models.Sequential()

#STEP 1: ADDING CONVOLUTIONAL LAYER
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[256, 256, 3]))

#STEP 2: APPLYING MAX POLLING  池化层Pooling 
cnn.add(tf.keras.layers.MaxPool2D(pool_size=(2, 2), strides=(2,2)))

#STEP 3: FLATTENING
cnn.add(tf.keras.layers.Flatten())

#STEP 4: FULL CONNECTION   densely-connected NN layer
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

#STEP 5: OUTPUT LAYER
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# Part 3 - Training the CNN
# 1.Compiling the CNN
# 2.Training the CNN on the Training set and evaluating it on the Test set

# %%
#1 Compiling the CNN
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

#2 Training the CNN on the Training set and evaluating it on the Test set
fitmodel = cnn.fit(x = training_set, validation_data = test_set, epochs = 3)
# Out:
# Epoch 1/3
# 251/251 [==============================] - 170s 669ms/step - loss: 0.1863 - accuracy: 0.9563 - val_loss: 3.0870 - val_accuracy: 0.6080
# Epoch 2/3
# 251/251 [==============================] - 168s 669ms/step - loss: 0.1407 - accuracy: 0.9685 - val_loss: 3.3450 - val_accuracy: 0.5971
# Epoch 3/3
# 251/251 [==============================] - 192s 763ms/step - loss: 0.0993 - accuracy: 0.9809 - val_loss: 3.3974 - val_accuracy: 0.6055

# %%
accuracy = fitmodel.history['accuracy']
plt.plot(range(len(accuracy)), accuracy, 'bo', label = 'accuracy')
plt.legend()

# %% [markdown]
# Part 4 - 预测图片

# %%
imagePath = "/Users/zhanghaisheng/study/imgs/cat_dog/training_set/training_set/cats/cat.1441.jpg"
image = tf.keras.preprocessing.image.load_img(imagePath,target_size = (256, 256))
image
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8A752575E0>

# %%
inputArr = tf.keras.preprocessing.image.img_to_array(image)
inputArr.shape
inputArr = np.expand_dims(inputArr, axis = 0)
result = cnn.predict(inputArr)
result.shape
print(result)
print(result[0])
print(result[0][0])
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
prediction
# Out:
# [[1.430879e-09]]
# [1.430879e-09]
# 1.430879e-09
# 'cat'

# %%
imagePath = "/Users/zhanghaisheng/study/imgs/cat_dog/training_set/training_set/dogs/dog.1441.jpg"
image2 = tf.keras.preprocessing.image.load_img(imagePath,target_size = (256, 256))
image2
inputArr2 = tf.keras.preprocessing.image.img_to_array(image2)
inputArr2.shape
inputArr2 = np.expand_dims(inputArr2, axis = 0)
result2 = cnn.predict(inputArr2)
result2.shape
print(result2)
print(result2[0])
print(result2[0][0])
if result2[0][0] == 1:
  prediction2 = 'dog'
else:
  prediction2 = 'cat'
prediction2
# Out:
# [[0.9881763]]
# [0.9881763]
# 0.9881763
# 'cat'

# %% [markdown]
# 验证错误，不知道为啥，都是cat
