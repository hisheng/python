# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.arange(0,5,0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
x = [1, 2, 3]
y = np.array([[1, 2], [3, 4], [5, 6]])
plt.plot(x, y)
# Out:
# [<matplotlib.lines.Line2D at 0x7f9267f2c820>,
#  <matplotlib.lines.Line2D at 0x7f9267f2c880>]

# %% [markdown]
# 准备数据

# %%
import os
train_dir = '/Users/zhanghaisheng/study/imgs/cat_dog/training_set/training_set/'
test_dir = '/Users/zhanghaisheng/study/imgs/cat_dog/test_set/test_set/'
rows = 64
cols = 64
channels = 3
train_images=[]

for file in os.listdir(train_dir):
    print(file)
    if file != 'DS_Store':
        path=os.path.join(train_dir,file)+'/'
        for i in os.listdir(path):
            print(path)
            if i != '_DS_Store':
                train_images.append(path+i)

print(train_images)
# Out:
# dogs
# cats
# .DS_Store
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# /var/folders/6m/xtkyqwyj5r520p_8kpgz9cq40000gp/T/ipykernel_97000/935516391.py in <module>
#      11     if file != 'DS_Store':
#      12         path=os.path.join(train_dir,file)+'/'
# ---> 13         for i in os.listdir(path):
#      14             if i != '_DS_Store':
#      15                 train_images.append(path+i)
#
# NotADirectoryError: [Errno 20] Not a directory: '/Users/zhanghaisheng/study/imgs/cat_dog/training_set/training_set/.DS_Store/'

# %%
train_images += [path+i for i in os.listdir(path) if i != '_DS_Store']
